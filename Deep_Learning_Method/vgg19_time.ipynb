# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os

from keras.models import load_model
from sklearn.datasets import load_files   
from keras.utils import np_utils
from glob import glob
from keras import applications
from keras.preprocessing.image import ImageDataGenerator 
from keras import optimizers
from keras.models import Sequential,Model,load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D,GlobalAveragePooling2D
from keras.callbacks import TensorBoard,ReduceLROnPlateau,ModelCheckpoint
from keras.callbacks import TensorBoard
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
tbCallBack = TensorBoard(log_dir='./log_vgg_red_100',  # log 目录
                 histogram_freq=0,  # 按照何等频率（epoch）来计算直方图，0为不计算
#                  batch_size=32,     # 用多大量的数据计算直方图
                 write_graph=True,  # 是否存储网络结构图
                 write_grads=True, # 是否可视化梯度直方图
                 write_images=True,# 是否可视化参数
                 embeddings_freq=0, 
                 embeddings_layer_names=None, 
                 embeddings_metadata=None)

# %%
FAST_RUN = False
IMAGE_WIDTH=480
IMAGE_HEIGHT=744
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %%
filenames = os.listdir("./train/")
ra_dataframe  = pd.read_csv('./rough_data.csv', header=None)
categories = []
for filename in filenames:
    dummy,right  = filename.split("_",1)
    info,right = right.split("_",1)
    number = info[0:-1]
    dire   = info[-1]
    row = 0
    if dire == 'L':
        row = (int(number) - 1)*2
    else:
        row = (int(number) - 1)*2 + 1
    ra_value = ra_dataframe.iloc[row,0]
    if ra_value < 1.6:
        categories.append(1)
    else:
        categories.append(0)
df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})
df
# Out:
#             filename  category
# 0    photo_31L_3.jpg         1
# 1    photo_21R_1.jpg         1
# 2    photo_30L_2.jpg         0
# 3     photo_5L_1.jpg         0
# 4    photo_34R_1.jpg         1
# 5    photo_51L_3.jpg         1
# 6     photo_3L_1.jpg         0
# 7    photo_36R_1.jpg         1
# 8     photo_6R_2.jpg         0
# 9    photo_66L_3.jpg         0
# 10    photo_2R_2.jpg         0
# 11   photo_66R_2.jpg         0
# 12    photo_8L_2.jpg         1
# 13   photo_53L_2.jpg         0
# 14   photo_19R_2.jpg         1
# 15   photo_16R_1.jpg         0
# 16   photo_37L_2.jpg         1
# 17   photo_49L_1.jpg         1
# 18   photo_14R_3.jpg         0
# 19   photo_71R_1.jpg         0
# 20   photo_30R_1.jpg         0
# 21   photo_43R_2.jpg         0
# 22   photo_33L_1.jpg         0
# 23   photo_46L_2.jpg         0
# 24   photo_19L_2.jpg         1
# 25   photo_60L_2.jpg         0
# 26   photo_40R_3.jpg         1
# 27   photo_58R_3.jpg         0
# 28   photo_56L_2.jpg         1
# 29   photo_63L_2.jpg         0
# ..               ...       ...
# 408  photo_23L_3.jpg         1
# 409  photo_73R_2.jpg         1
# 410  photo_60R_2.jpg         0
# 411  photo_35L_1.jpg         1
# 412  photo_37L_3.jpg         1
# 413  photo_64R_3.jpg         0
# 414  photo_18R_3.jpg         0
# 415  photo_29R_1.jpg         0
# 416   photo_4L_2.jpg         0
# 417  photo_41R_2.jpg         0
# 418  photo_67L_2.jpg         1
# 419  photo_14R_2.jpg         0
# 420  photo_20R_3.jpg         1
# 421   photo_3L_3.jpg         0
# 422  photo_10L_3.jpg         0
# 423  photo_62R_3.jpg         0
# 424  photo_35R_1.jpg         1
# 425  photo_27L_2.jpg         1
# 426  photo_57L_2.jpg         0
# 427  photo_58L_1.jpg         0
# 428  photo_72R_3.jpg         0
# 429  photo_72L_2.jpg         0
# 430  photo_58L_3.jpg         0
# 431   photo_5R_3.jpg         0
# 432  photo_18R_1.jpg         0
# 433  photo_15L_1.jpg         0
# 434  photo_19R_3.jpg         1
# 435  photo_13R_2.jpg         0
# 436  photo_36L_2.jpg         1
# 437  photo_17L_2.jpg         1
#
# [438 rows x 2 columns]

# %%
df['category'].value_counts().plot.bar()

# %%
img_height,img_width = 480,744
#If imagenet weights are being loaded, 
#input must have a static square shape (one of (128, 128), (160, 160), (192, 192), or (224, 224))
base_model = applications.vgg19.VGG19(weights= None, include_top=False, input_shape= (img_height,img_width,3))
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.7)(x)
predictions = Dense(2, activation= 'softmax')(x)
model = Model(inputs = base_model.input, outputs = predictions)
from keras.optimizers import SGD, Adam
# sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
adam = Adam(lr=0.0001)
model.compile(optimizer= adam, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 480, 744, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 480, 744, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 480, 744, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 240, 372, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 240, 372, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 240, 372, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 120, 186, 128)     0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 120, 186, 256)     295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 120, 186, 256)     590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 120, 186, 256)     590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 120, 186, 256)     590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 60, 93, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 60, 93, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 60, 93, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 60, 93, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 60, 93, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 30, 46, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 30, 46, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 30, 46, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 30, 46, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 30, 46, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 15, 23, 512)       0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 20,025,410
# Trainable params: 20,025,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience=10)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)
callbacks = [tbCallBack,earlystop, learning_rate_reduction]

# %%
df["category"] = df["category"].replace({0: 'NG', 1: 'GO'})

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=10

# %%
train_datagen = ImageDataGenerator(rescale=1./255,)
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "./train/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 350 validated image filenames belonging to 2 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "./train/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=20
)
# Out:
# Found 88 validated image filenames belonging to 2 classes.

# %%
epochs=3 if FAST_RUN else 100
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=10,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 24/35 [===================>..........] - ETA: 9s - loss: 0.6940 - acc: 0.4792

# %%
model.save_weights("model_vgg_time.h5")

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['acc'], color='b', label="Training accuracy")
ax2.plot(history.history['val_acc'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %%
filenames = os.listdir("./test/")
ra_dataframe  = pd.read_csv('./rough_data.csv', header=None)
categories = []
for filename in filenames:
    dummy,right  = filename.split("_",1)
    info,right = right.split("_",1)
    number = info[0:-1]
    dire   = info[-1]
    row = 0
    if dire == 'L':
        row = (int(number) - 1)*2
    else:
        row = (int(number) - 1)*2 + 1
    ra_value = ra_dataframe.iloc[row,0]
    if ra_value < 1.6:
        categories.append(1)
    else:
        categories.append(0)
test_df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})
test_df
# Out:
#            filename  category
# 0   photo_19R_2.jpg         1
# 1   photo_19L_2.jpg         1
# 2   photo_17R_1.jpg         1
# 3   photo_17R_2.jpg         1
# 4   photo_10L_1.jpg         0
# 5   photo_17L_1.jpg         1
# 6   photo_19L_1.jpg         1
# 7   photo_17L_3.jpg         1
# 8   photo_10R_3.jpg         0
# 9   photo_17R_3.jpg         1
# 10  photo_19R_1.jpg         1
# 11  photo_10L_2.jpg         0
# 12  photo_10R_2.jpg         0
# 13  photo_19L_3.jpg         1
# 14  photo_10R_1.jpg         0
# 15  photo_10L_3.jpg         0
# 16  photo_19R_3.jpg         1
# 17  photo_17L_2.jpg         1

# %%
test_filenames = os.listdir("./test")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "./test/", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 18 validated image filenames.

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))

# %%
test_df['category'] = np.argmax(predict, axis=-1)

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)

# %%
test_df['category'] = test_df['category'].replace({ 'dog': 1, 'cat': 0 })

# %%
test_df['category'].value_counts().plot.bar()

# %%
sample_test = test_df.head(18)
sample_test.head()
plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    img = load_img("./test/"+filename, target_size=IMAGE_SIZE)
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(category) + ')' )
plt.tight_layout()
plt.show()
